# %%
# !git config --global user.email 'aorestrepor@correo.udistrital.edu.co'
# !git config --global user.name 'AndresRestrepoRodriguez'
# pruebaaaaaaaaaaaa

# %%
# !rm -r /content/Emotional_Time_Series

# %%
# !git clone -b develop https://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@github.com/AndresRestrepoRodriguez/Emotional_Time_Series.git
# Out:
# Cloning into 'Emotional_Time_Series'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 61 (delta 4), reused 10 (delta 2), pack-reused 45
# Unpacking objects: 100% (61/61), done.

# %%
from Emotional_Time_Series import processing_ts, plotting_tool, utils

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import os
import seaborn as sns
sns.set()
sns.set_style("whitegrid")
# %matplotlib inline

# %%
metrics = ["engagement", "excitation", "stress", "relax", "interest", "focus"]
colors_metrics = {"engagement": "#BF2F21",
                  "excitation": "#EB9108",
                  "stress": "#C715CD",
                  "relax": "#75602A",
                  "interest": "#2037C6",
                  "focus": "#319B1A"}
dict_colores = {"VL-DNA": "#E8846E",
                "TE-DNA": "#F1E58E",
                "OP-ASSOC": "#8DD47A",
                "OP-PRON": "#A09F90",
                "OP-LIS": "#74BAEE",
                "OP-JOIN": "#4083AF",
                "OP-TRA": "#C574EE",
                "OP-ORD": "#FD95DE",
                "OP-DLG": "#FBA64C"}

# %%
id = "0"
lesson = "1"
path_root = "/content/drive/MyDrive/Tesis/data/"
path_data = "/content/drive/MyDrive/Tesis/data/id_"+id+"/lesson_"+lesson+"/data_1secs_extra_exe.csv"
data = pd.read_csv(path_data)
results_csv_path = os.path.join(path_root, "id_"+id, "lesson_"+lesson, 'results_participant_'+id+'_lesson_'+lesson+'.csv')
results_df = pd.read_csv(results_csv_path)
path_to_save = os.path.join(path_root, "id_"+id, "lesson_"+lesson, 'results_participant_'+id+'_lesson_'+lesson+'.json')

# %%
data_ts = processing_ts.process_datetime(data)
activities = processing_ts.process_activities(data_ts)
unique_act = processing_ts.get_unique_activities(activities)
diff_time_activities = processing_ts.get_time_diff_activities(activities)
results_time_dict = processing_ts.generate_results_time(diff_time_activities, results_df)
utils.save_dict_as_json(results_time_dict, path_to_save)

# %%
plotting_tool.get_plot_ts(dataframe_ts=data_ts, metrics_list=metrics, colors_metrics=colors_metrics, 
                          zone_data=activities, dict_colors=dict_colores, unique_actitivities=unique_act)

# %%
# Out:
#    sequence  activity  total_questions  correct  errors
# 0         0   general               18       18       0
# 1         2    OP-TRA                3        3       0
# 2         4  OP-ASSOC                5        5       0
# 3         5    OP-DLG                4        4       0
